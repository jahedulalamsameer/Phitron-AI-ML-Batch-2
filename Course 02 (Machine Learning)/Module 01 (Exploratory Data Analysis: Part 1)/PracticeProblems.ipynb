# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("penguins")

# %% [markdown]
# ### **Task 1**

# %%
print(f"Number of samples: {df.shape[0]}")
print(f"Number of potential features {df.shape[1]}")
# Out:
# Number of samples: 344
# Number of potential features 7

# %%
df.head(7)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female

# %%
df.sample(5)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 244     Gentoo  Biscoe            42.9           13.1              215.0
# 167  Chinstrap   Dream            50.5           19.6              201.0
# 338     Gentoo  Biscoe            47.2           13.7              214.0
# 104     Adelie  Biscoe            37.9           18.6              193.0
# 195  Chinstrap   Dream            45.5           17.0              196.0
#
#      body_mass_g     sex
# 244       5000.0  Female
# 167       4050.0    Male
# 338       4925.0  Female
# 104       2925.0  Female
# 195       3500.0  Female

# %% [markdown]
# ### **Task 2**

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df.isna().sum().idxmax()
# Out:
# 'sex'

# %% [markdown]
# ### **Task 3**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### **Task 4**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 24.9 KB

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
print(f"Max body_mass_g: {df["body_mass_g"].max()}")
print(f"Avg flipper_length_mm: {df["flipper_length_mm"].mean():.2f}")
# Out:
# Max body_mass_g: 6300.0
# Avg flipper_length_mm: 200.92

# %% [markdown]
# ### **Task 5**

# %%
sns.countplot(x=df["species"])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
df["species"].value_counts().idxmax()
# Out:
# 'Adelie'

# %% [markdown]
# ### **Task 6**

# %%
display(pd.DataFrame({"Count":df["island"].value_counts(), "Percentage":(df["island"].value_counts(normalize=True))*100}))
# Out:
#            Count  Percentage
# island
# Biscoe       168   48.837209
# Dream        124   36.046512
# Torgersen     52   15.116279

# %% [markdown]
# ### **Task 7**

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
plt.pie(df["sex"].value_counts(),  labels=df["sex"].value_counts().index, autopct="%0.1f%%")
plt.show()
