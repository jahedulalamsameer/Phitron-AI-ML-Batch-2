# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
students = pd.read_csv("students.csv")
sales = pd.read_csv("sales.csv")

# %% [markdown]
# #### **Problem 1**

# %%
sales["date"]
# Out:
# 0      2025-01-01
# 1      2025-01-02
# 2      2025-01-03
# 3      2025-01-04
# 4      2025-01-05
#           ...
# 115    2025-04-26
# 116    2025-04-27
# 117    2025-04-28
# 118    2025-04-29
# 119    2025-04-30
# Name: date, Length: 120, dtype: str

# %%
sales["date"] = pd.to_datetime(sales["date"])
sales["month"] = sales["date"].dt.month_name()

# %%
sns.lineplot(data=sales, x="month", y="sales")
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %% [markdown]
# #### **Problem 2**

# %%
students.columns
# Out:
# Index(['number_courses', 'time_study', 'Marks', 'student_id', 'class_level',
#        'subject', 'study_hours', 'test_score', 'week', 'attendance_rate',
#        'gender', 'hostel', 'Tshirt_size', 'class_name'],
#       dtype='str')

# %%
sns.relplot(kind="scatter", data=students, x="study_hours", y="test_score", hue="gender")

# %% [markdown]
# #### **Problem 3**

# %%
sns.relplot(kind="scatter", data=students, x="study_hours", y="test_score", hue="gender", col="subject")

# %% [markdown]
# #### **Problem 4**

# %%
sns.displot(kind="kde", data=students, x="Marks", hue="gender", fill=True)

# %% [markdown]
# #### **Problem 5**

# %%
sns.countplot(data=students, x="subject", hue="gender")
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %% [markdown]
# #### **Problem 6**

# %%
sns.lmplot(data=students, x="study_hours", y="Marks")

# %% [markdown]
# #### **Problem 7**

# %%
students.columns
# Out:
# Index(['number_courses', 'time_study', 'Marks', 'student_id', 'class_level',
#        'subject', 'study_hours', 'test_score', 'week', 'attendance_rate',
#        'gender', 'hostel', 'Tshirt_size', 'class_name'],
#       dtype='str')

# %%
sns.pairplot(data=students[["subject","study_hours","test_score","attendance_rate","gender"]])
