# %% [markdown]
# Problem 1

# %%
import numpy as np

celsius = [35,40,32,29,38,33,36,37,35,34,39]
celsius = np.array(celsius)

fahrenheit = (celsius * 1.8) + 32

print(fahrenheit)
print(type(fahrenheit))
print(fahrenheit.dtype)
# Out:
# [ 95.  104.   89.6  84.2 100.4  91.4  96.8  98.6  95.   93.2 102.2]
# <class 'numpy.ndarray'>
# float64

# %% [markdown]
# Problem 2

# %%
lap_sec = [122, 120, 115, 110, 111, 112, 105, 113, 100]
lap = np.array(lap_sec)

print(lap.dtype)
print(lap.shape)
print(lap.size)
print(lap/60)
# Out:
# int64
# (9,)
# 9
# [2.03333333 2.         1.91666667 1.83333333 1.85       1.86666667
#  1.75       1.88333333 1.66666667]
