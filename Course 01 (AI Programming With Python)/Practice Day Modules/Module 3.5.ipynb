# %% [markdown]
# Problem 1

# %%
def create_file(filename, content):
    with open(filename, 'w') as f:
        f.writelines(content)

filename = input()
content = input()
create_file(filename,content)

# %% [markdown]
# Problem 2

# %%
def read_lines(filename):
    with open(filename, 'r') as f:
        lst = f.readlines()
        print(*[f"{i}: {name}" for i, name in enumerate(lst,1)],sep="")

read_lines('data.txt')
# Out:
# 1: Apple
# 2: Banana
# 3: Cherry

# %% [markdown]
# Problem 3

# %%
def add_log(message):
    with open('log.txt','a') as f:
        f.writelines(message+"\n")

add_log("User logged in")
add_log("File uploaded")

# %% [markdown]
# Problem 4

# %%
def read_from_position(filename, position):
    with open(filename,'r') as f:
        f.seek(position)
        print(f.read())

filename = input()
position = int(input())

read_from_position(filename,position)
# Out:
# Welcome to the world of AI
# Tell me is this ok or overwhelming?
# Is the era beneficial?
# Yes it is
# Hi

# %% [markdown]
# Problem 5

# %%
def safe_read(filename):
    try:
        with open(filename,'r') as f:
            file = f.readlines()
    except FileNotFoundError:
        print("Error: File not found")
    else:
        print(*file,sep="")
    finally:
        print("Operation complete")
        

safe_read("sample.txt")
# Out:
# Hello world
# Welcome to the world of AI
# Tell me is this ok or overwhelming?
# Is the era beneficial?
# Yes it is
# Hi
# Operation complete
