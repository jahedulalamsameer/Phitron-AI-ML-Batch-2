# %% [markdown]
# Problem 1

# %%
def introduce(name,age):
    if int(age):
        print(f"My name is {name} and I am {age} years old.")

name, age = input().split(" ")
introduce(name,age)
# Out:
# My name is Rahim and I am 28 years old.

# %% [markdown]
# Problem 2

# %%
data = input("Enter data as a list: ").split(" ")
batch_size = int(input("Enter batch size: "))

def batch_generator(data,batch_size):
    if list(data):
        for i in range(0,len(data),batch_size):
            yield data[i:i+batch_size]

batch = batch_generator(data, batch_size)

for i in range(batch_size):
    print(next(batch))
# Out:
# ['1', '2', '3']
# ['4', '5', '6']
# ['7', '8']

# %% [markdown]
# Problem 3

# %%
lst = [1,2,3,4]

squared = list(map(lambda x: x**2, lst))
print(squared)
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# Problem 4

# %%
def power(base, exponent=2):
    return int(base) ** int(exponent)

data = input().split(" ")

if len(data)==1:
    print(power(data[0]))
else:
    print(power(data[0],data[1]))
# Out:
# 125

# %% [markdown]
# Problem 5

# %%
lst = [1,2,3,4,5,6]

even_sqr = list(map(lambda x:x**2, list(filter(lambda x: x%2==0, lst))))

print(even_sqr)
# Out:
# [4, 16, 36]
